# %%
import numpy as np
import os
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import data
file_path = 'C:/Users/seanj/Documents/GitHub/business_trends/data/clean_biz.csv'
biz = pd.read_csv(file_path,keep_default_na=False)

biz.head()
# Out:
#    LicenceRSN  Status  Year  Month            BusinessType BusinessSubType  \
# 0     2333487  Issued  2015      3  Apartment House Strata             N/A
# 1     2333489  Issued  2014     11  Apartment House Strata             N/A
# 2     2333490  Issued  2014     12  Apartment House Strata             N/A
# 3     2333491  Issued  2014     12  Apartment House Strata             N/A
# 4     2333492  Issued  2014     11  Apartment House Strata             N/A
#
#   PostalCode  LocalArea                          Coordinates
# 0    V6Z 2N1   Downtown  49.2741705397492, -123.132003087572
# 1    V5S 4B5  Killarney  49.2156668051544, -123.029020213594
# 2    V6E 4C1   West End     49.277365821302, -123.1337614345
# 3    V6E 4C1   West End     49.277365821302, -123.1337614345
# 4    V6E 4L5   West End  49.2878720003484, -123.128230314012

# %%
# Count Plot
sns.countplot(x='Year', data=biz)
plt.title('Business Licenses by Year')
plt.show()

# %%
# Count Plot
sns.countplot(x='Month', data=biz)
plt.title('Business Licenses by Month')
plt.show()

# %%
# Count Plot
sns.countplot(x='LocalArea', data=biz)
plt.title('Business Licenses by Business Type')
plt.xticks(rotation=60)
plt.tight_layout()
plt.show()
